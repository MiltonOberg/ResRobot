# %% [markdown]
# # Explorations

# %%
from backend.connect_to_api import ResRobot

resrobot = ResRobot()

resrobot.access_id_from_location("Umeå")
# Out:
# Name                                               extId
# UMEÅ                                               740098065
# Umeå Centralstation                                740000190
# Umeå Busstation                                    740020461
# Umeå Östra station                                 740001581
# Umeå Vasaplan                                      740020116
# Umeå Airport                                       740025159
# Umeå Ålidhem centrum                               740023156
# Umeå Ålidhöjd                                      740045439
# Umeå Älvans väg                                    740045410
# Umeå Alviksgränd                                   740045280

# %%
resrobot.access_id_from_location("Göteborg")
# Out:
# Name                                               extId
# GÖTEBORG                                           740098001
# Göteborg Centralstation                            740000002
# Göteborg Sävenäs lokstation                        740016365
# GÖTEBORG GAMLESTADEN                               740098526
# Göteborg Korsvägen                                 740015578
# Göteborg Kungsportsplatsen                         740016358
# Göteborg Stenpiren                                 740072430
# Göteborg Eketrägatan                               740025624
# Göteborg Vårväderstorget                           740025707
# Göteborg Axel Dahlströms torg                      740025608

# %%
umea_id = 740000190
gothenburg_id = 740000002

trips = resrobot.trips(umea_id, gothenburg_id)

len(trips["Trip"])
# Out:
# 5

# %%
trips["Trip"][2]["LegList"]
# Out:
# {'Leg': [{'Origin': {'name': 'Umeå Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Umeå Centralstation@X=20266810@Y=63830064@U=1@L=740000190@',
#     'extId': '740000190',
#     'lon': 20.26681,
#     'lat': 63.830064,
#     'routeIdx': 7,
#     'prognosisType': 'PROGNOSED',
#     'time': '21:16:00',
#     'date': '2025-01-21',
#     'minimumChangeDuration': 'PT10M'},
#    'Destination': {'name': 'Stockholm Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#     'extId': '740000001',
#     'lon': 18.058151,
#     'lat': 59.330136,
#     'routeIdx': 19,
#     'prognosisType': 'PROGNOSED',
#     'time': '07:01:00',
#     'date': '2025-01-22',
#     'minimumChangeDuration': 'PT20M'},
#    'Notes': {'Note': [{'value': 'Endast 2 klass',
#       'key': 'AA',
#       'type': 'A',
#       'routeIdxFrom': 7,
#       'routeIdxTo': 19,
#       'txtN': 'Endast 2 klass'},
#      {'value': 'Bistrovagn',
#       'key': 'AD',
#       'type': 'A',
#       'routeIdxFrom': 7,
#       'routeIdxTo': 19,
#       'txtN': 'Bistrovagn'},
#      {'value': 'Obligatorisk platsbokning',
#       'key': 'AF',
#       'type': 'A',
#       'routeIdxFrom': 7,
#       'routeIdxTo': 19,
#       'txtN': 'Obligatorisk platsbokning'},
#      {'value': 'Rullstolslyft',
#       'key': 'AN',
#       'type': 'A',
#       'routeIdxFrom': 7,
#       'routeIdxTo': 19,
#       'txtN': 'Rullstolslyft'},
#      {'value': 'EU förordning 2021/782',
#       'key': 'EJ',
#       'type': 'A',
#       'routeIdxFrom': 7,
#       'routeIdxTo': 19,
#       'txtN': 'EU förordning 2021/782'},
#      {'value': 'Sov- och liggvagn',
#       'key': 'SL',
#       'type': 'A',
#       'routeIdxFrom': 7,
#       'routeIdxTo': 19,
#       'txtN': 'Sov- och liggvagn'}]},
#    'JourneyDetailRef': {'ref': '1|46793|0|1|21012025'},
#    'JourneyStatus': 'P',
#    'Product': [{'icon': {'res': 'prod_gen'},
#      'operatorInfo': {'name': 'SJ',
#       'nameS': '74',
#       'nameN': '74',
#       'nameL': 'SJ',
#       'id': '74'},
#      'name': 'Nattåg 91',
#      'internalName': 'Nattåg 91',
#      'displayNumber': '91',
#      'num': '91',
#      'line': '91',
#      'lineId': '1074009100003',
#      'catOut': 'JNT',
#      'catIn': 'JNT',
#      'catCode': '2',
#      'cls': '4',
#      'catOutS': 'JNT',
#      'catOutL': 'Nattåg',
#      'operatorCode': '74',
#      'operator': 'SJ',
#      'admin': '074___',
#      'routeIdxFrom': 7,
#      'routeIdxTo': 19,
#      'matchId': '91;91;23363'}],
#    'Stops': {'Stop': [{'name': 'Umeå Centralstation',
#       'id': 'A=1@O=Umeå Centralstation@X=20266810@Y=63830064@U=1@L=740000190@',
#       'extId': '740000190',
#       'routeIdx': 7,
#       'lon': 20.26681,
#       'lat': 63.830064,
#       'depTime': '21:16:00',
#       'depDate': '2025-01-21',
#       'depDir': 'Stockholm Centralstation',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Umeå Östra station',
#       'id': 'A=1@O=Umeå Östra station@X=20293454@Y=63817659@U=1@L=740001581@',
#       'extId': '740001581',
#       'routeIdx': 8,
#       'lon': 20.293454,
#       'lat': 63.817659,
#       'depTime': '21:23:00',
#       'depDate': '2025-01-21',
#       'arrTime': '21:22:00',
#       'arrDate': '2025-01-21',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Nordmaling Resecentrum/Station (Nordmaling-AC kn)',
#       'id': 'A=1@O=Nordmaling Resecentrum/Station (Nordmaling-AC kn)@X=19486285@Y=63578303@U=1@L=740001583@',
#       'extId': '740001583',
#       'routeIdx': 9,
#       'lon': 19.486285,
#       'lat': 63.578303,
#       'depTime': '21:56:00',
#       'depDate': '2025-01-21',
#       'arrTime': '21:56:00',
#       'arrDate': '2025-01-21',
#       'minimumChangeDuration': 'PT5M'},
#      {'name': 'Örnsköldsvik Centralstation',
#       'id': 'A=1@O=Örnsköldsvik Centralstation@X=18704305@Y=63289282@U=1@L=740001570@',
#       'extId': '740001570',
#       'routeIdx': 10,
#       'lon': 18.704305,
#       'lat': 63.289282,
#       'depTime': '22:35:00',
#       'depDate': '2025-01-21',
#       'arrTime': '22:35:00',
#       'arrDate': '2025-01-21',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Kramfors station',
#       'id': 'A=1@O=Kramfors station@X=17778182@Y=62929111@U=1@L=740000220@',
#       'extId': '740000220',
#       'routeIdx': 11,
#       'lon': 17.778182,
#       'lat': 62.929111,
#       'depTime': '23:28:00',
#       'depDate': '2025-01-21',
#       'arrTime': '23:28:00',
#       'arrDate': '2025-01-21',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Härnösand station',
#       'id': 'A=1@O=Härnösand station@X=17928635@Y=62635182@U=1@L=740000253@',
#       'extId': '740000253',
#       'routeIdx': 12,
#       'lon': 17.928635,
#       'lat': 62.635182,
#       'depTime': '00:07:00',
#       'depDate': '2025-01-22',
#       'arrTime': '00:07:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Sundsvall Centralstation',
#       'id': 'A=1@O=Sundsvall Centralstation@X=17315633@Y=62386873@U=1@L=740000130@',
#       'extId': '740000130',
#       'routeIdx': 13,
#       'lon': 17.315633,
#       'lat': 62.386873,
#       'depTime': '01:17:00',
#       'depDate': '2025-01-22',
#       'arrTime': '01:02:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Hudiksvall station',
#       'id': 'A=1@O=Hudiksvall station@X=17109034@Y=61724494@U=1@L=740000187@',
#       'extId': '740000187',
#       'routeIdx': 14,
#       'lon': 17.109034,
#       'lat': 61.724494,
#       'depTime': '03:00:00',
#       'depDate': '2025-01-22',
#       'arrTime': '02:56:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Söderhamn station',
#       'id': 'A=1@O=Söderhamn station@X=17035682@Y=61299600@U=1@L=740000154@',
#       'extId': '740000154',
#       'routeIdx': 15,
#       'lon': 17.035682,
#       'lat': 61.2996,
#       'depTime': '03:35:00',
#       'depDate': '2025-01-22',
#       'arrTime': '03:35:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Gävle Centralstation',
#       'id': 'A=1@O=Gävle Centralstation@X=17151221@Y=60676118@U=1@L=740000210@',
#       'extId': '740000210',
#       'routeIdx': 16,
#       'lon': 17.151221,
#       'lat': 60.676118,
#       'depTime': '04:51:00',
#       'depDate': '2025-01-22',
#       'arrTime': '04:31:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT10M'},
#      {'Notes': {'Note': [{'value': 'Stannar endast för avstigande',
#          'key': 'text.realtime.stop.entry.disabled',
#          'type': 'R',
#          'txtN': 'Stannar endast för avstigande'}]},
#       'name': 'Uppsala Centralstation',
#       'id': 'A=1@O=Uppsala Centralstation@X=17646086@Y=59858531@U=1@L=740000005@',
#       'extId': '740000005',
#       'routeIdx': 17,
#       'lon': 17.646086,
#       'lat': 59.858531,
#       'arrTime': '05:53:00',
#       'arrDate': '2025-01-22',
#       'boarding': False,
#       'minimumChangeDuration': 'PT10M'},
#      {'Notes': {'Note': [{'value': 'Stannar endast för avstigande',
#          'key': 'text.realtime.stop.entry.disabled',
#          'type': 'R',
#          'txtN': 'Stannar endast för avstigande'}]},
#       'name': 'Arlanda Centralstation (Sigtuna kn)',
#       'id': 'A=1@O=Arlanda Centralstation (Sigtuna kn)@X=17929201@Y=59649469@U=1@L=740000556@',
#       'extId': '740000556',
#       'routeIdx': 18,
#       'lon': 17.929201,
#       'lat': 59.649469,
#       'arrTime': '06:35:00',
#       'arrDate': '2025-01-22',
#       'boarding': False,
#       'minimumChangeDuration': 'PT2H'},
#      {'name': 'Stockholm Centralstation',
#       'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#       'extId': '740000001',
#       'routeIdx': 19,
#       'lon': 18.058151,
#       'lat': 59.330136,
#       'arrPrognosisType': 'PROGNOSED',
#       'arrTime': '07:01:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT20M'}]},
#    'JourneyDetail': {'ref': '1|46793|0|1|21012025',
#     'dayOfOperation': '2025-01-21'},
#    'id': '0',
#    'idx': 0,
#    'name': 'Nattåg 91',
#    'number': '91',
#    'category': 'JNT',
#    'type': 'JNY',
#    'reachable': True,
#    'waitingState': 'UNDEF',
#    'direction': 'Stockholm Centralstation',
#    'directionFlag': '1',
#    'duration': 'PT9H45M',
#    'minimumChangeDuration': 'PT20M'},
#   {'Origin': {'name': 'Stockholm Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#     'extId': '740000001',
#     'lon': 18.058151,
#     'lat': 59.330136,
#     'routeIdx': 0,
#     'prognosisType': 'PROGNOSED',
#     'time': '08:14:00',
#     'date': '2025-01-22',
#     'minimumChangeDuration': 'PT20M'},
#    'Destination': {'name': 'Göteborg Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#     'extId': '740000002',
#     'lon': 11.973479,
#     'lat': 57.708895,
#     'routeIdx': 18,
#     'prognosisType': 'PROGNOSED',
#     'time': '12:57:00',
#     'date': '2025-01-22',
#     'minimumChangeDuration': 'PT15M'},
#    'Notes': {'Note': [{'value': '2 kl har ej reservering',
#       'key': 'AB',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 5,
#       'txtN': '2 kl har ej reservering'},
#      {'value': '2 kl har ej reservering',
#       'key': 'AB',
#       'type': 'A',
#       'routeIdxFrom': 7,
#       'routeIdxTo': 10,
#       'txtN': '2 kl har ej reservering'},
#      {'value': '2 kl har ej reservering',
#       'key': 'AB',
#       'type': 'A',
#       'routeIdxFrom': 13,
#       'routeIdxTo': 18,
#       'txtN': '2 kl har ej reservering'},
#      {'value': 'Obligatorisk platsbokning',
#       'key': 'AF',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 18,
#       'txtN': 'Obligatorisk platsbokning'},
#      {'value': 'Rullstolslyft',
#       'key': 'AN',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 18,
#       'txtN': 'Rullstolslyft'},
#      {'value': 'WiFi',
#       'key': 'AW',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 18,
#       'txtN': 'WiFi'},
#      {'value': 'EU förordning 2021/782',
#       'key': 'EJ',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 18,
#       'txtN': 'EU förordning 2021/782'},
#      {'value': 'Servering finns ej',
#       'key': 'SI',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 18,
#       'txtN': 'Servering finns ej'}]},
#    'JourneyDetailRef': {'ref': '1|172527|0|1|22012025'},
#    'JourneyStatus': 'P',
#    'Product': [{'icon': {'res': 'prod_gen'},
#      'operatorInfo': {'name': 'SJ',
#       'nameS': '74',
#       'nameN': '74',
#       'nameL': 'SJ',
#       'id': '74'},
#      'name': 'Regional Tåg 165',
#      'internalName': 'Regional Tåg 165',
#      'displayNumber': '165',
#      'num': '165',
#      'line': '165',
#      'lineId': '1074016500001',
#      'catOut': 'JRE',
#      'catIn': 'JRE',
#      'catCode': '2',
#      'cls': '4',
#      'catOutS': 'JRE',
#      'catOutL': 'Regional Tåg',
#      'operatorCode': '74',
#      'operator': 'SJ',
#      'admin': '074___',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 18,
#      'matchId': '165;165;12047'}],
#    'Stops': {'Stop': [{'name': 'Stockholm Centralstation',
#       'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#       'extId': '740000001',
#       'routeIdx': 0,
#       'lon': 18.058151,
#       'lat': 59.330136,
#       'depPrognosisType': 'PROGNOSED',
#       'depTime': '08:14:00',
#       'depDate': '2025-01-22',
#       'depDir': 'Göteborg Centralstation',
#       'minimumChangeDuration': 'PT20M'},
#      {'Notes': {'Note': [{'value': 'Stannar endast för påstigande',
#          'key': 'text.realtime.stop.exit.disabled',
#          'type': 'R',
#          'txtN': 'Stannar endast för påstigande'}]},
#       'name': 'Sundbyberg station',
#       'id': 'A=1@O=Sundbyberg station@X=17970938@Y=59361032@U=1@L=740000773@',
#       'extId': '740000773',
#       'routeIdx': 1,
#       'lon': 17.970938,
#       'lat': 59.361032,
#       'depTime': '08:23:00',
#       'depDate': '2025-01-22',
#       'alighting': False,
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Bålsta station (Håbo kn)',
#       'id': 'A=1@O=Bålsta station (Håbo kn)@X=17532813@Y=59568754@U=1@L=740000660@',
#       'extId': '740000660',
#       'routeIdx': 2,
#       'lon': 17.532813,
#       'lat': 59.568754,
#       'depTime': '08:42:00',
#       'depDate': '2025-01-22',
#       'arrTime': '08:42:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Enköping station',
#       'id': 'A=1@O=Enköping station@X=17086741@Y=59644327@U=1@L=740000072@',
#       'extId': '740000072',
#       'routeIdx': 3,
#       'lon': 17.086741,
#       'lat': 59.644327,
#       'depTime': '08:55:00',
#       'depDate': '2025-01-22',
#       'arrTime': '08:55:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT8M'},
#      {'name': 'Västerås Centralstation',
#       'id': 'A=1@O=Västerås Centralstation@X=16551712@Y=59607705@U=1@L=740000099@',
#       'extId': '740000099',
#       'routeIdx': 4,
#       'lon': 16.551712,
#       'lat': 59.607705,
#       'depTime': '09:12:00',
#       'depDate': '2025-01-22',
#       'arrTime': '09:10:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT8M'},
#      {'name': 'Köping station',
#       'id': 'A=1@O=Köping station@X=16004215@Y=59506675@U=1@L=740000167@',
#       'extId': '740000167',
#       'routeIdx': 5,
#       'lon': 16.004215,
#       'lat': 59.506675,
#       'depTime': '09:29:00',
#       'depDate': '2025-01-22',
#       'arrTime': '09:29:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT5M'},
#      {'name': 'Arboga station',
#       'id': 'A=1@O=Arboga station@X=15841061@Y=59397105@U=1@L=740000262@',
#       'extId': '740000262',
#       'routeIdx': 6,
#       'lon': 15.841061,
#       'lat': 59.397105,
#       'depTime': '09:41:00',
#       'depDate': '2025-01-22',
#       'arrTime': '09:40:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT5M'},
#      {'name': 'Örebro Centralstation',
#       'id': 'A=1@O=Örebro Centralstation@X=15211348@Y=59278942@U=1@L=740000133@',
#       'extId': '740000133',
#       'routeIdx': 7,
#       'lon': 15.211348,
#       'lat': 59.278942,
#       'depTime': '10:15:00',
#       'depDate': '2025-01-22',
#       'arrTime': '10:02:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Örebro Södra station',
#       'id': 'A=1@O=Örebro Södra station@X=15202332@Y=59269989@U=1@L=740000361@',
#       'extId': '740000361',
#       'routeIdx': 8,
#       'lon': 15.202332,
#       'lat': 59.269989,
#       'depTime': '10:18:00',
#       'depDate': '2025-01-22',
#       'arrTime': '10:18:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT1H30M'},
#      {'name': 'Kumla station',
#       'id': 'A=1@O=Kumla station@X=15140280@Y=59126377@U=1@L=740000192@',
#       'extId': '740000192',
#       'routeIdx': 9,
#       'lon': 15.14028,
#       'lat': 59.126377,
#       'depTime': '10:28:00',
#       'depDate': '2025-01-22',
#       'arrTime': '10:28:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Hallsberg station',
#       'id': 'A=1@O=Hallsberg station@X=15110391@Y=59066698@U=1@L=740000077@',
#       'extId': '740000077',
#       'routeIdx': 10,
#       'lon': 15.110391,
#       'lat': 59.066698,
#       'depTime': '10:39:00',
#       'depDate': '2025-01-22',
#       'arrTime': '10:36:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Laxå station',
#       'id': 'A=1@O=Laxå station@X=14616658@Y=58989391@U=1@L=740000194@',
#       'extId': '740000194',
#       'routeIdx': 11,
#       'lon': 14.616658,
#       'lat': 58.989391,
#       'depTime': '10:55:00',
#       'depDate': '2025-01-22',
#       'arrTime': '10:55:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Töreboda station',
#       'id': 'A=1@O=Töreboda station@X=14128391@Y=58706024@U=1@L=740000183@',
#       'extId': '740000183',
#       'routeIdx': 12,
#       'lon': 14.128391,
#       'lat': 58.706024,
#       'depTime': '11:20:00',
#       'depDate': '2025-01-22',
#       'arrTime': '11:20:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT8M'},
#      {'name': 'Skövde Centralstation',
#       'id': 'A=1@O=Skövde Centralstation@X=13853195@Y=58390898@U=1@L=740000008@',
#       'extId': '740000008',
#       'routeIdx': 13,
#       'lon': 13.853195,
#       'lat': 58.390898,
#       'depTime': '11:36:00',
#       'depDate': '2025-01-22',
#       'arrTime': '11:35:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Falköping Centralstation',
#       'id': 'A=1@O=Falköping Centralstation@X=13553791@Y=58176101@U=1@L=740000060@',
#       'extId': '740000060',
#       'routeIdx': 14,
#       'lon': 13.553791,
#       'lat': 58.176101,
#       'depTime': '11:52:00',
#       'depDate': '2025-01-22',
#       'arrTime': '11:51:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT8M'},
#      {'name': 'Herrljunga station',
#       'id': 'A=1@O=Herrljunga station@X=13021279@Y=58079188@U=1@L=740000040@',
#       'extId': '740000040',
#       'routeIdx': 15,
#       'lon': 13.021279,
#       'lat': 58.079188,
#       'depTime': '12:07:00',
#       'depDate': '2025-01-22',
#       'arrTime': '12:07:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT8M'},
#      {'name': 'Vårgårda station',
#       'id': 'A=1@O=Vårgårda station@X=12810285@Y=58031204@U=1@L=740000569@',
#       'extId': '740000569',
#       'routeIdx': 16,
#       'lon': 12.810285,
#       'lat': 58.031204,
#       'depTime': '12:15:00',
#       'depDate': '2025-01-22',
#       'arrTime': '12:15:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Alingsås station',
#       'id': 'A=1@O=Alingsås station@X=12532491@Y=57926857@U=1@L=740000018@',
#       'extId': '740000018',
#       'routeIdx': 17,
#       'lon': 12.532491,
#       'lat': 57.926857,
#       'depTime': '12:26:00',
#       'depDate': '2025-01-22',
#       'arrTime': '12:26:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT7M'},
#      {'name': 'Göteborg Centralstation',
#       'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#       'extId': '740000002',
#       'routeIdx': 18,
#       'lon': 11.973479,
#       'lat': 57.708895,
#       'arrPrognosisType': 'PROGNOSED',
#       'arrTime': '12:57:00',
#       'arrDate': '2025-01-22',
#       'minimumChangeDuration': 'PT15M'}]},
#    'JourneyDetail': {'ref': '1|172527|0|1|22012025',
#     'dayOfOperation': '2025-01-22'},
#    'id': '1',
#    'idx': 1,
#    'name': 'Regional Tåg 165',
#    'number': '165',
#    'category': 'JRE',
#    'type': 'JNY',
#    'reachable': True,
#    'waitingState': 'UNDEF',
#    'direction': 'Göteborg Centralstation',
#    'directionFlag': '1',
#    'duration': 'PT4H43M'}]}

# %%
import pandas as pd 

# pd.DataFrame(trips["Trip"])
legs = []

for trip in trips.get("Trip"):
    legs.append(trip.get("LegList").get("Leg"))

# Umeå -> Stockholm
legs[0][0]["Origin"], legs[0][0]["Destination"]
# Out:
# ({'name': 'Umeå Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Umeå Centralstation@X=20266810@Y=63830064@U=1@L=740000190@',
#   'extId': '740000190',
#   'lon': 20.26681,
#   'lat': 63.830064,
#   'routeIdx': 7,
#   'prognosisType': 'PROGNOSED',
#   'time': '21:16:00',
#   'date': '2025-01-21',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Stockholm Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#   'extId': '740000001',
#   'lon': 18.058151,
#   'lat': 59.330136,
#   'routeIdx': 19,
#   'prognosisType': 'PROGNOSED',
#   'time': '07:01:00',
#   'date': '2025-01-22',
#   'minimumChangeDuration': 'PT20M'})

# %%
# Stockholm -> Göteborg
legs[0][1]["Origin"], legs[0][1]["Destination"]
# Out:
# ({'name': 'Stockholm Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#   'extId': '740000001',
#   'lon': 18.058151,
#   'lat': 59.330136,
#   'routeIdx': 0,
#   'prognosisType': 'PROGNOSED',
#   'time': '08:12:00',
#   'date': '2025-01-22',
#   'minimumChangeDuration': 'PT20M'},
#  {'name': 'Göteborg Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#   'extId': '740000002',
#   'lon': 11.973479,
#   'lat': 57.708895,
#   'routeIdx': 3,
#   'prognosisType': 'PROGNOSED',
#   'time': '11:41:00',
#   'date': '2025-01-22',
#   'minimumChangeDuration': 'PT15M'})

# %%
next_available_trip = legs[0]
df = pd.DataFrame(next_available_trip)
df
# Out:
#                                               Origin  \
# 0  {'name': 'Umeå Centralstation', 'type': 'ST', ...
# 1  {'name': 'Stockholm Centralstation', 'type': '...
#
#                                          Destination  \
# 0  {'name': 'Stockholm Centralstation', 'type': '...
# 1  {'name': 'Göteborg Centralstation', 'type': 'S...
#
#                                                Notes  \
# 0  {'Note': [{'value': 'Endast 2 klass', 'key': '...
# 1  {'Note': [{'value': 'X2000', 'key': 'VX', 'typ...
#
#                   JourneyDetailRef JourneyStatus  \
# 0  {'ref': '1|46793|0|1|21012025'}             P
# 1  {'ref': '1|35070|0|1|22012025'}             P
#
#                                              Product  \
# 0  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 1  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
#
#                                                Stops  \
# 0  {'Stop': [{'name': 'Umeå Centralstation', 'id'...
# 1  {'Stop': [{'name': 'Stockholm Centralstation',...
#
#                                        JourneyDetail id  idx          name  \
# 0  {'ref': '1|46793|0|1|21012025', 'dayOfOperatio...  0    0     Nattåg 91
# 1  {'ref': '1|35070|0|1|22012025', 'dayOfOperatio...  1    1  Snabbtåg 425
#
#   number category type  reachable waitingState                 direction  \
# 0     91      JNT  JNY       True        UNDEF  Stockholm Centralstation
# 1    425      JST  JNY       True        UNDEF   Göteborg Centralstation
#
#   directionFlag duration minimumChangeDuration
# 0             1  PT9H45M                 PT20M
# 1             1  PT3H29M                   NaN

# %%
df_trip = df[["name", "Stops"]]
df_trip
# Out:
#            name                                              Stops
# 0     Nattåg 91  {'Stop': [{'name': 'Umeå Centralstation', 'id'...
# 1  Snabbtåg 425  {'Stop': [{'name': 'Stockholm Centralstation',...

# %%
df_trip["Stops"]
# Out:
# 0    {'Stop': [{'name': 'Umeå Centralstation', 'id'...
# 1    {'Stop': [{'name': 'Stockholm Centralstation',...
# Name: Stops, dtype: object

# %%
all_stops = pd.json_normalize(df["Stops"].dropna(), "Stop")
all_stops.head()
# Out:
#                                                 name  \
# 0                                Umeå Centralstation
# 1                                 Umeå Östra station
# 2  Nordmaling Resecentrum/Station (Nordmaling-AC kn)
# 3                        Örnsköldsvik Centralstation
# 4                                   Kramfors station
#
#                                                   id      extId  routeIdx  \
# 0  A=1@O=Umeå Centralstation@X=20266810@Y=6383006...  740000190         7
# 1  A=1@O=Umeå Östra station@X=20293454@Y=63817659...  740001581         8
# 2  A=1@O=Nordmaling Resecentrum/Station (Nordmali...  740001583         9
# 3  A=1@O=Örnsköldsvik Centralstation@X=18704305@Y...  740001570        10
# 4  A=1@O=Kramfors station@X=17778182@Y=62929111@U...  740000220        11
#
#          lon        lat   depTime     depDate                    depDir  \
# 0  20.266810  63.830064  21:16:00  2025-01-21  Stockholm Centralstation
# 1  20.293454  63.817659  21:23:00  2025-01-21                       NaN
# 2  19.486285  63.578303  21:56:00  2025-01-21                       NaN
# 3  18.704305  63.289282  22:35:00  2025-01-21                       NaN
# 4  17.778182  62.929111  23:28:00  2025-01-21                       NaN
#
#   minimumChangeDuration   arrTime     arrDate boarding Notes.Note  \
# 0                 PT10M       NaN         NaN      NaN        NaN
# 1                 PT10M  21:22:00  2025-01-21      NaN        NaN
# 2                  PT5M  21:56:00  2025-01-21      NaN        NaN
# 3                 PT10M  22:35:00  2025-01-21      NaN        NaN
# 4                 PT10M  23:28:00  2025-01-21      NaN        NaN
#
#   arrPrognosisType depPrognosisType
# 0              NaN              NaN
# 1              NaN              NaN
# 2              NaN              NaN
# 3              NaN              NaN
# 4              NaN              NaN

# %%
stops = all_stops[["name", "arrTime", "arrDate", "depTime", "depDate", "lon", "lat"]]
stops
# Out:
#                                                  name   arrTime     arrDate  \
# 0                                 Umeå Centralstation       NaN         NaN
# 1                                  Umeå Östra station  21:22:00  2025-01-21
# 2   Nordmaling Resecentrum/Station (Nordmaling-AC kn)  21:56:00  2025-01-21
# 3                         Örnsköldsvik Centralstation  22:35:00  2025-01-21
# 4                                    Kramfors station  23:28:00  2025-01-21
# 5                                   Härnösand station  00:07:00  2025-01-22
# 6                            Sundsvall Centralstation  01:02:00  2025-01-22
# 7                                  Hudiksvall station  02:56:00  2025-01-22
# 8                                   Söderhamn station  03:35:00  2025-01-22
# 9                                Gävle Centralstation  04:31:00  2025-01-22
# 10                             Uppsala Centralstation  05:53:00  2025-01-22
# 11                Arlanda Centralstation (Sigtuna kn)  06:35:00  2025-01-22
# 12                           Stockholm Centralstation  07:01:00  2025-01-22
# 13                           Stockholm Centralstation       NaN         NaN
# 14                         Katrineholm Centralstation  09:03:00  2025-01-22
# 15                              Skövde Centralstation  10:22:00  2025-01-22
# 16                            Göteborg Centralstation  11:41:00  2025-01-22
#
#      depTime     depDate        lon        lat
# 0   21:16:00  2025-01-21  20.266810  63.830064
# 1   21:23:00  2025-01-21  20.293454  63.817659
# 2   21:56:00  2025-01-21  19.486285  63.578303
# 3   22:35:00  2025-01-21  18.704305  63.289282
# 4   23:28:00  2025-01-21  17.778182  62.929111
# 5   00:07:00  2025-01-22  17.928635  62.635182
# 6   01:17:00  2025-01-22  17.315633  62.386873
# 7   03:00:00  2025-01-22  17.109034  61.724494
# 8   03:35:00  2025-01-22  17.035682  61.299600
# 9   04:51:00  2025-01-22  17.151221  60.676118
# 10       NaN         NaN  17.646086  59.858531
# 11       NaN         NaN  17.929201  59.649469
# 12       NaN         NaN  18.058151  59.330136
# 13  08:12:00  2025-01-22  18.058151  59.330136
# 14  09:04:00  2025-01-22  16.208324  58.996591
# 15  10:22:00  2025-01-22  13.853195  58.390898
# 16       NaN         NaN  11.973479  57.708895

# %%
stops = stops.drop_duplicates(subset="name").reset_index(drop=True)
stops
# Out:
#                                                  name   arrTime     arrDate  \
# 0                                 Umeå Centralstation       NaN         NaN
# 1                                  Umeå Östra station  21:22:00  2025-01-21
# 2   Nordmaling Resecentrum/Station (Nordmaling-AC kn)  21:56:00  2025-01-21
# 3                         Örnsköldsvik Centralstation  22:35:00  2025-01-21
# 4                                    Kramfors station  23:28:00  2025-01-21
# 5                                   Härnösand station  00:07:00  2025-01-22
# 6                            Sundsvall Centralstation  01:02:00  2025-01-22
# 7                                  Hudiksvall station  02:56:00  2025-01-22
# 8                                   Söderhamn station  03:35:00  2025-01-22
# 9                                Gävle Centralstation  04:31:00  2025-01-22
# 10                             Uppsala Centralstation  05:53:00  2025-01-22
# 11                Arlanda Centralstation (Sigtuna kn)  06:35:00  2025-01-22
# 12                           Stockholm Centralstation  07:01:00  2025-01-22
# 13                         Katrineholm Centralstation  09:03:00  2025-01-22
# 14                              Skövde Centralstation  10:22:00  2025-01-22
# 15                            Göteborg Centralstation  11:41:00  2025-01-22
#
#      depTime     depDate        lon        lat
# 0   21:16:00  2025-01-21  20.266810  63.830064
# 1   21:23:00  2025-01-21  20.293454  63.817659
# 2   21:56:00  2025-01-21  19.486285  63.578303
# 3   22:35:00  2025-01-21  18.704305  63.289282
# 4   23:28:00  2025-01-21  17.778182  62.929111
# 5   00:07:00  2025-01-22  17.928635  62.635182
# 6   01:17:00  2025-01-22  17.315633  62.386873
# 7   03:00:00  2025-01-22  17.109034  61.724494
# 8   03:35:00  2025-01-22  17.035682  61.299600
# 9   04:51:00  2025-01-22  17.151221  60.676118
# 10       NaN         NaN  17.646086  59.858531
# 11       NaN         NaN  17.929201  59.649469
# 12       NaN         NaN  18.058151  59.330136
# 13  09:04:00  2025-01-22  16.208324  58.996591
# 14  10:22:00  2025-01-22  13.853195  58.390898
# 15       NaN         NaN  11.973479  57.708895

# %%
stops["time"] = stops["arrTime"].fillna(stops["depTime"])
stops["date"] = stops["arrDate"].fillna(stops["depDate"])

# %%
import folium

geographical_map = folium.Map(
    location=[stops["lat"].mean(), stops["lon"].mean()], zoom_start=5
)

for _, row in stops.iterrows():
    folium.Marker(
        location=[row["lat"], row["lon"]],
        popup=f"{row['name']}<br>{row['time']}<br>{row['date']}",
    ).add_to(geographical_map)

geographical_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ded267443454fefefd1d4d01be0fb79a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ded267443454fefefd1d4d01be0fb79a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ded267443454fefefd1d4d01be0fb79a = L.map(
#                 &quot;map_ded267443454fefefd1d4d01be0fb79a&quot;,
#                 {
#                     center: [61.256325375, 17.421104812499998],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_915c4bd182e8090ae4ba64b743993262 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_915c4bd182e8090ae4ba64b743993262.addTo(map_ded267443454fefefd1d4d01be0fb79a);
#
#
#             var marker_af1f32b4b43bcc4fcd21c29c2279817e = L.marker(
#                 [63.830064, 20.26681],
#                 {
# }
#             ).addTo(map_ded267443454fefefd1d4d01be0fb79a);
#
#
#         var popup_9797ec43a10ade03979d0fd9f0921ec9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d063c105a8f04f771ab2f5437af02de = $(`&lt;div id=&quot;html_2d063c105a8f04f771ab2f5437af02de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Umeå Centralstation&lt;br&gt;21:16:00&lt;br&gt;2025-01-21&lt;/div&gt;`)[0];
#                 popup_9797ec43a10ade03979d0fd9f0921ec9.setContent(html_2d063c105a8f04f771ab2f5437af02de);
#
#
#
#         marker_af1f32b4b43bcc4fcd21c29c2279817e.bindPopup(popup_9797ec43a10ade03979d0fd9f0921ec9)
#         ;
#
#
#
#
#             var marker_a97ac1edad2c56a63e5a3a5c1d83c5bc = L.marker(
#                 [63.817659, 20.293454],
#                 {
# }
#             ).addTo(map_ded267443454fefefd1d4d01be0fb79a);
#
#
#         var popup_9151abb356d32ec0691bb7420e6d950f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0d3d23538824669300f9def7e53b5ff = $(`&lt;div id=&quot;html_d0d3d23538824669300f9def7e53b5ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Umeå Östra station&lt;br&gt;21:22:00&lt;br&gt;2025-01-21&lt;/div&gt;`)[0];
#                 popup_9151abb356d32ec0691bb7420e6d950f.setContent(html_d0d3d23538824669300f9def7e53b5ff);
#
#
#
#         marker_a97ac1edad2c56a63e5a3a5c1d83c5bc.bindPopup(popup_9151abb356d32ec0691bb7420e6d950f)
#         ;
#
#
#
#
#             var marker_da4c401e951378e50d9cf4e110c0cd8a = L.marker(
#                 [63.578303, 19.486285],
#                 {
# }
#             ).addTo(map_ded267443454fefefd1d4d01be0fb79a);
#
#
#         var popup_058a5954e6569a3ea421ea0cd0a5f3da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd0a739a3442ad7e5b350695c2012093 = $(`&lt;div id=&quot;html_cd0a739a3442ad7e5b350695c2012093&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nordmaling Resecentrum/Station (Nordmaling-AC kn)&lt;br&gt;21:56:00&lt;br&gt;2025-01-21&lt;/div&gt;`)[0];
#                 popup_058a5954e6569a3ea421ea0cd0a5f3da.setContent(html_cd0a739a3442ad7e5b350695c2012093);
#
#
#
#         marker_da4c401e951378e50d9cf4e110c0cd8a.bindPopup(popup_058a5954e6569a3ea421ea0cd0a5f3da)
#         ;
#
#
#
#
#             var marker_3db0c764bb2804585fb40b7c5f5b028a = L.marker(
#                 [63.289282, 18.704305],
#                 {
# }
#             ).addTo(map_ded267443454fefefd1d4d01be0fb79a);
#
#
#         var popup_0bb30a49afc2f4ca479a62df0fbe3ad4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36605fec1bb82cc76fd49143f150db5c = $(`&lt;div id=&quot;html_36605fec1bb82cc76fd49143f150db5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Örnsköldsvik Centralstation&lt;br&gt;22:35:00&lt;br&gt;2025-01-21&lt;/div&gt;`)[0];
#                 popup_0bb30a49afc2f4ca479a62df0fbe3ad4.setContent(html_36605fec1bb82cc76fd49143f150db5c);
#
#
#
#         marker_3db0c764bb2804585fb40b7c5f5b028a.bindPopup(popup_0bb30a49afc2f4ca479a62df0fbe3ad4)
#         ;
#
#
#
#
#             var marker_fe7a17bd56f101f38882466d8685fe61 = L.marker(
#                 [62.929111, 17.778182],
#                 {
# }
#             ).addTo(map_ded267443454fefefd1d4d01be0fb79a);
#
#
#         var popup_33a10f80f6f813a857e0fa160372559c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0811f9a34932925eb5f2313134bd905 = $(`&lt;div id=&quot;html_d0811f9a34932925eb5f2313134bd905&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kramfors station&lt;br&gt;23:28:00&lt;br&gt;2025-01-21&lt;/div&gt;`)[0];
#                 popup_33a10f80f6f813a857e0fa160372559c.setContent(html_d0811f9a34932925eb5f2313134bd905);
